# %% [markdown]
# Chamando Libraries

# %%
import pandas as pd

# %% [markdown]
# Formatando Float

# %%
pd.options.display.float_format = "{:.2f}".format

# %% [markdown]
# Chamando Arquivo_DF
#
# ` Lembrando que por se tratar de um arquivo PT-BR, precisamos mudar o encoding para o ISO-8859-1 para que possamos ler o arquivo, além disso - o separador estava originalmente como ";" sendo assim é necessário também declarar esse separador - além disso, por se tratar de números em PT-BR a formatação de decimal estará como "," sendo assim necessário atualizar para "."`

# %%
url = "https://raw.githubusercontent.com/hidekiaoyanagi/df_alura_SUS_21/main/A212755189_28_143_208.csv"
df = pd.read_csv(url, encoding="ISO-8859-1", skiprows=3, skipfooter= 3 , sep=";", thousands= '.', decimal= ",")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.

# %% [markdown]
# Remover NA do DF

# %%
df.dropna(inplace= True)

# %%
dados_estados = df


dados_estados.replace("-",0 , inplace= True)

dados_estados
# Out:
#       Unidade da Federação     2008/Jan  ...       2021/Ago           Total
# 0              11 Rondônia   1091658.61  ...     9126101.17    859818177.61
# 1                  12 Acre    665896.23  ...     3211586.60    361469740.72
# 2              13 Amazonas   3593778.70  ...    17413494.69   1576840808.09
# 3               14 Roraima    465523.12  ...     2952392.49    262943857.88
# 4                  15 Pará  14400485.38  ...    31918002.33   3798775471.87
# 5                 16 Amapá    841750.93  ...              0    239235328.66
# 6             17 Tocantins   2691952.26  ...     7785798.87    859130084.80
# 7              21 Maranhão   8292533.79  ...    32404838.31   3224340000.88
# 8                 22 Piauí   6244662.89  ...    20867038.89   1913788807.50
# 9                 23 Ceará  12136685.45  ...    41926574.10   5510579290.44
# 10  24 Rio Grande do Norte   4607313.87  ...    25035902.23   2219361303.14
# 11              25 Paraíba   8580988.49  ...    22309732.68   2188788395.92
# 12           26 Pernambuco  11403623.74  ...    83347480.67   7262932345.94
# 13              27 Alagoas   4813217.67  ...    19405787.89   1854479014.04
# 14              28 Sergipe   2069998.73  ...    11556610.22    999183532.04
# 15                29 Bahia  16502402.19  ...    88591200.90   8128006279.75
# 16         31 Minas Gerais  36737238.40  ...   193981333.55  17447603412.30
# 17       32 Espírito Santo   4339410.10  ...    36272642.70   2936739836.07
# 18       33 Rio de Janeiro  19262626.17  ...   101698436.48   8882781805.96
# 19            35 São Paulo  74734672.12  ...   328079700.38  35200023154.10
# 20               41 Paraná  31353259.16  ...   147664376.34  12522255711.51
# 21       42 Santa Catarina  13408198.10  ...    76837226.93   6644315239.37
# 22    43 Rio Grande do Sul  25625523.90  ...   114865242.94  11066891191.48
# 23   50 Mato Grosso do Sul   4202791.30  ...    30064692.74   1961256386.27
# 24          51 Mato Grosso   3699820.62  ...    30415136.69   1886447328.30
# 25                52 Goiás  12595871.36  ...    56936003.77   4252388876.78
# 26     53 Distrito Federal   3720571.62  ...    22230655.33   2176310798.17
# 27                   Total 328082454.90  ...  1556897989.89 146236686179.59
#
# [28 rows x 166 columns]

# %% [markdown]
# Criando um DataViz com o matplotlib

# %%
#Importando as Bibliotecas necessárias!
  #Lembrando que o próprio pandas, tem dentro de seu dataviz o matplotlib - no entanto, o que gostáriamos de fazer aqui é ajustar detalhes internos
  #Para isso, será necessário chamar a própria library para que a gente tenha esse grau de granularidade.
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %%
#Em que eixo X , será o estado que estamos trabalhando.
# Em que eixo Y, será o valor gasto para a data que gostariamos de trabalhar.
# kind = bar, declara o tipo de gráfico que gostariamos de exibir - nesse caso bar de barra.
#figsize, coloca a dimensão do nosso gráfico em largura x altura.
#o ticket.StrMethodFormatter serve para que possamos exibir nossos dados do eixo y de uma maneira mais agradavel.
  #para esse gráfico X:(faz referencia a um valor X qualquer do eixo) - estará separado nos milhares por "," e decimal por "." - além de conter apenas
  #2 casas decimais.

#utilizaremos o df.drop(df.tail(1)) para remover a ultima linha do nosso DF, pois ela é uma linha de total(somatória) e sendo assim cria
#uma distorção dentro do nosso DataViz.



if len(dados_estados['Unidade da Federação']) == len(df['Unidade da Federação']):
  dados_estados = df.drop(df.tail(1).index)

if len(dados_estados.columns) == len(df.columns):
  dados_estados = dados_estados.drop(dados_estados.columns[-1],axis=1)

ax = dados_estados.plot(x="Unidade da Federação", y="2008/Ago", kind="bar", figsize=(9,6))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))

plt.title("Valor Gasto em R$ por unidade da federação")
plt.show()

# %%
#Em que eixo X , será o estado que estamos trabalhando.
# Em que eixo Y, será o valor gasto para a data que gostariamos de trabalhar.
# kind = bar, declara o tipo de gráfico que gostariamos de exibir - nesse caso bar de barra.
#figsize, coloca a dimensão do nosso gráfico em largura x altura.
#o ticket.StrMethodFormatter serve para que possamos exibir nossos dados do eixo y de uma maneira mais agradavel.
  #para esse gráfico X:(faz referencia a um valor X qualquer do eixo) - estará separado nos milhares por "," e decimal por "." - além de conter apenas
  #2 casas decimais.

#utilizaremos o df.drop(df.tail(1)) para remover a ultima linha do nosso DF, pois ela é uma linha de total(somatória) e sendo assim cria
#uma distorção dentro do nosso DataViz.
#Caso a qntd de linhas do dados_estados for igual a quantiadade de linhas do nosso df original, vamos remover a ultima.
#Para pegar a ultima data, iremos remover a nossa aba de total pois ela causa distorções em um DATAVIZ(para esse caso)
#E chamaremos de ultima_data a ultima coluna do nosso dataframe: dados_estados


if len(dados_estados['Unidade da Federação']) == len(df['Unidade da Federação']):
  dados_estados = df.drop(df.tail(1).index)

if len(dados_estados.columns) == len(df.columns):
  dados_estados = dados_estados.drop(dados_estados.columns[-1],axis=1)


ultima_data = dados_estados.columns[-1]

dados_estados[ultima_data]=dados_estados[ultima_data].astype(float)

ax = dados_estados.plot(x="Unidade da Federação", y= ultima_data, kind="bar", figsize=(9,6))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))

plt.title("Valor Gasto em R$ por unidade da federação")
plt.show()

# %%
colunas_usaveis = dados_estados.mean().index.tolist()
colunas_usaveis.insert(0, "Unidade da Federação")
colunas_usaveis
# Out:
# ['Unidade da Federação',
#  '2008/Jan',
#  '2008/Fev',
#  '2008/Mar',
#  '2008/Abr',
#  '2008/Mai',
#  '2008/Jun',
#  '2008/Jul',
#  '2008/Ago',
#  '2008/Set',
#  '2008/Out',
#  '2008/Nov',
#  '2008/Dez',
#  '2009/Jan',
#  '2009/Fev',
#  '2009/Mar',
#  '2009/Abr',
#  '2009/Mai',
#  '2009/Jun',
#  '2009/Jul',
#  '2009/Ago',
#  '2009/Out',
#  '2009/Nov',
#  '2009/Dez',
#  '2010/Jan',
#  '2010/Fev',
#  '2010/Mar',
#  '2010/Abr',
#  '2010/Mai',
#  '2010/Jun',
#  '2010/Jul',
#  '2010/Ago',
#  '2010/Set',
#  '2010/Out',
#  '2010/Nov',
#  '2010/Dez',
#  '2011/Jan',
#  '2011/Fev',
#  '2011/Mar',
#  '2011/Abr',
#  '2011/Mai',
#  '2011/Jun',
#  '2011/Jul',
#  '2011/Ago',
#  '2011/Set',
#  '2011/Out',
#  '2011/Nov',
#  '2011/Dez',
#  '2012/Jan',
#  '2012/Fev',
#  '2012/Mar',
#  '2012/Abr',
#  '2012/Mai',
#  '2012/Jun',
#  '2012/Jul',
#  '2012/Ago',
#  '2012/Set',
#  '2012/Out',
#  '2012/Nov',
#  '2012/Dez',
#  '2013/Jan',
#  '2013/Fev',
#  '2013/Mar',
#  '2013/Abr',
#  '2013/Mai',
#  '2013/Jun',
#  '2013/Jul',
#  '2013/Ago',
#  '2013/Set',
#  '2013/Out',
#  '2013/Nov',
#  '2013/Dez',
#  '2014/Jan',
#  '2014/Fev',
#  '2014/Mar',
#  '2014/Abr',
#  '2014/Mai',
#  '2014/Jun',
#  '2014/Jul',
#  '2014/Ago',
#  '2014/Set',
#  '2014/Out',
#  '2014/Nov',
#  '2014/Dez',
#  '2015/Jan',
#  '2015/Fev',
#  '2015/Mar',
#  '2015/Abr',
#  '2015/Mai',
#  '2015/Jun',
#  '2015/Jul',
#  '2015/Ago',
#  '2015/Set',
#  '2015/Out',
#  '2015/Nov',
#  '2015/Dez',
#  '2016/Jan',
#  '2016/Fev',
#  '2016/Mar',
#  '2016/Abr',
#  '2016/Mai',
#  '2016/Jun',
#  '2016/Jul',
#  '2016/Ago',
#  '2016/Set',
#  '2016/Out',
#  '2016/Nov',
#  '2016/Dez',
#  '2017/Jan',
#  '2017/Fev',
#  '2017/Mar',
#  '2017/Abr',
#  '2017/Mai',
#  '2017/Jun',
#  '2017/Jul',
#  '2017/Ago',
#  '2017/Set',
#  '2017/Out',
#  '2017/Nov',
#  '2017/Dez',
#  '2018/Jan',
#  '2018/Fev',
#  '2018/Mar',
#  '2018/Abr',
#  '2018/Mai',
#  '2018/Jun',
#  '2018/Jul',
#  '2018/Ago',
#  '2018/Set',
#  '2018/Out',
#  '2018/Nov',
#  '2018/Dez',
#  '2019/Jan',
#  '2019/Fev',
#  '2019/Mar',
#  '2019/Abr',
#  '2019/Mai',
#  '2019/Jun',
#  '2019/Jul',
#  '2019/Ago',
#  '2019/Set',
#  '2019/Out',
#  '2019/Nov',
#  '2019/Dez',
#  '2020/Jan',
#  '2020/Fev',
#  '2020/Mar',
#  '2020/Abr',
#  '2020/Mai',
#  '2020/Jun',
#  '2020/Jul',
#  '2020/Ago',
#  '2020/Set',
#  '2020/Out',
#  '2020/Nov',
#  '2020/Dez',
#  '2021/Jan',
#  '2021/Fev',
#  '2021/Mar',
#  '2021/Abr',
#  '2021/Mai',
#  '2021/Jun',
#  '2021/Jul',
#  '2021/Ago']

# %%
usaveis = dados_estados[colunas_usaveis]
usaveis = usaveis.set_index("Unidade da Federação")

usaveis
# Out:
#                           2008/Jan     2008/Fev  ...     2021/Jul     2021/Ago
# Unidade da Federação                             ...
# 11 Rondônia             1091658.61   2303736.65  ...  10383272.89   9126101.17
# 12 Acre                  665896.23   1140167.20  ...   3884752.29   3211586.60
# 13 Amazonas             3593778.70   5460498.83  ...  19720814.02  17413494.69
# 14 Roraima               465523.12    541585.42  ...   2926502.35   2952392.49
# 15 Pará                14400485.38  14971834.11  ...  34654554.91  31918002.33
# 16 Amapá                 841750.93    935697.28  ...   4178106.27         0.00
# 17 Tocantins            2691952.26   3954485.46  ...   7762399.33   7785798.87
# 21 Maranhão             8292533.79  10440858.77  ...  40108537.52  32404838.31
# 22 Piauí                6244662.89   7845474.50  ...  23076986.99  20867038.89
# 23 Ceará               12136685.45  20271904.10  ...  73963773.31  41926574.10
# 24 Rio Grande do Norte  4607313.87   7546392.84  ...  28845357.39  25035902.23
# 25 Paraíba              8580988.49   9050986.31  ...  23748222.18  22309732.68
# 26 Pernambuco          11403623.74  18904396.46  ...  93677963.34  83347480.67
# 27 Alagoas              4813217.67   6504989.59  ...  23677638.64  19405787.89
# 28 Sergipe              2069998.73   2766069.31  ...  15452727.58  11556610.22
# 29 Bahia               16502402.19  22038098.86  ... 109014614.18  88591200.90
# 31 Minas Gerais        36737238.40  56697837.35  ... 210648455.04 193981333.55
# 32 Espírito Santo       4339410.10   7161614.50  ...  45179292.57  36272642.70
# 33 Rio de Janeiro      19262626.17  23581216.45  ... 108886786.43 101698436.48
# 35 São Paulo           74734672.12 121839337.46  ... 379315637.93 328079700.38
# 41 Paraná              31353259.16  45551366.47  ... 151689447.35 147664376.34
# 42 Santa Catarina      13408198.10  20849369.60  ...  80175010.90  76837226.93
# 43 Rio Grande do Sul   25625523.90  47338004.76  ... 128568948.85 114865242.94
# 50 Mato Grosso do Sul   4202791.30   5493733.04  ...  25831953.20  30064692.74
# 51 Mato Grosso          3699820.62   6947298.88  ...  31563495.01  30415136.69
# 52 Goiás               12595871.36  18272185.92  ...  59021540.45  56936003.77
# 53 Distrito Federal     3720571.62   5939369.45  ...  24260713.04  22230655.33
#
# [27 rows x 163 columns]

# %%
ax = usaveis.T.plot(figsize=(10,6))
ax.legend(loc='center left', bbox_to_anchor=(1.1, 0.5))

# %%
##Criar Região para cada estado.
 #Utilizaremos o dataframe: dados_estados para inserir a categoria Região Administrativa

dados_estados = df
dados_estados.replace("-",0 , inplace= True)

#Observando o Dataframe, descobrir que cada região administrativa possui um código e ele é inserido
#no primeiro caractere do número do estado.
#Sendo assim, criamos um dict para ser o nosso depara de Código e Região.

regiao = {"1": "Norte", "2":"Nordeste", "3":"Sudeste","4":"Sul","5":"Centro-Oeste", "T": "Total"}

#com a utilização do slice, removemos todos os caracteres da string após o primeiro - já que nosso
#depara só utiliza o primeiro carac para verificação
dados_estados["Região"] = dados_estados["Unidade da Federação"].str.slice(0,1)

#utilizaremos a função .map(regiao) em que ele olhará o valor dentro de cada linhaxcoluna e verificará dentro
#do nosso dict qual seria o depara apropriado.
#vale lembrar que caso a gente não tenha mapeado de maneira completa, os valores não encontrados seriam
# NAN, então talvez vale colocar um count para esse tipo de situação para entender se foi assertivo o dict

dados_estados["Região"] = dados_estados["Região"].map(regiao)

# %%
#Considerando que nosso dataframe, possui 146 colunas.
#Fiquei com preguiça arrumar isso manualmente, sendo assim criei uma estrutura para colocar
#Estado e Região nas duas primeiras colunas e o resto ficar posterior a elas.

#Colunas que quero no começo:
colunas_principais = ['Unidade da Federação', 'Região']
#Essa função concatena nossa lista, fazendo com que as colunas principais fiquem no começo e depois
#a partir de todos as outras colunas, da drop nas duas que setamos no "colunas_principais"
#para evitar repetição e depois criamos em uma lista.

novo_layout = colunas_principais + (dados_estados.columns.drop(colunas_principais).tolist())
#por fim, declaramos que nosso dataframe "dados_estados" são os dados_estados com o sort realizado acima.
dados_estados = dados_estados[novo_layout]
dados_estados
# Out:
#       Unidade da Federação        Região  ...      2021/Jul       2021/Ago
# 0              11 Rondônia         Norte  ...   10383272.89     9126101.17
# 1                  12 Acre         Norte  ...    3884752.29     3211586.60
# 2              13 Amazonas         Norte  ...   19720814.02    17413494.69
# 3               14 Roraima         Norte  ...    2926502.35     2952392.49
# 4                  15 Pará         Norte  ...   34654554.91    31918002.33
# 5                 16 Amapá         Norte  ...    4178106.27              0
# 6             17 Tocantins         Norte  ...    7762399.33     7785798.87
# 7              21 Maranhão      Nordeste  ...   40108537.52    32404838.31
# 8                 22 Piauí      Nordeste  ...   23076986.99    20867038.89
# 9                 23 Ceará      Nordeste  ...   73963773.31    41926574.10
# 10  24 Rio Grande do Norte      Nordeste  ...   28845357.39    25035902.23
# 11              25 Paraíba      Nordeste  ...   23748222.18    22309732.68
# 12           26 Pernambuco      Nordeste  ...   93677963.34    83347480.67
# 13              27 Alagoas      Nordeste  ...   23677638.64    19405787.89
# 14              28 Sergipe      Nordeste  ...   15452727.58    11556610.22
# 15                29 Bahia      Nordeste  ...  109014614.18    88591200.90
# 16         31 Minas Gerais       Sudeste  ...  210648455.04   193981333.55
# 17       32 Espírito Santo       Sudeste  ...   45179292.57    36272642.70
# 18       33 Rio de Janeiro       Sudeste  ...  108886786.43   101698436.48
# 19            35 São Paulo       Sudeste  ...  379315637.93   328079700.38
# 20               41 Paraná           Sul  ...  151689447.35   147664376.34
# 21       42 Santa Catarina           Sul  ...   80175010.90    76837226.93
# 22    43 Rio Grande do Sul           Sul  ...  128568948.85   114865242.94
# 23   50 Mato Grosso do Sul  Centro-Oeste  ...   25831953.20    30064692.74
# 24          51 Mato Grosso  Centro-Oeste  ...   31563495.01    30415136.69
# 25                52 Goiás  Centro-Oeste  ...   59021540.45    56936003.77
# 26     53 Distrito Federal  Centro-Oeste  ...   24260713.04    22230655.33
# 27                   Total         Total  ... 1760217503.96  1556897989.89
#
# [28 rows x 166 columns]

# %%
import random
# ／ʕ •ᴥ•ʔ／ Escreva o Nome de seu estado - com acentuação se for o caso e preferenciamente direito. ／ʕ •ᴥ•ʔ／
seu_estado = "São Paulo"

if len(dados_estados['Unidade da Federação']) == 28:
  dados_estados = dados_estados.drop(27)


##pegando o index do seu estado

index_seu_estado = dados_estados.index[dados_estados['Unidade da Federação'].str.contains(seu_estado)].tolist()
index_seu_estado = index_seu_estado[0]
 

#criando uma lista de 5 randomica
randomico = random.sample(range(0, len(dados_estados)), 5)


#verificando se seu estado já existe na lista, senão existir tiramos o ultimo dado da lista e inserimos seu estado
if index_seu_estado in randomico:
  randomico
else:
  randomico.pop()
  randomico.append(index_seu_estado)

#inserindo os estados na variavel a ser plotada
random_estados = dados_estados.loc[randomico]
random_estados
# Out:
#      Unidade da Federação        Região  ...     2021/Jul      2021/Ago
# 0             11 Rondônia         Norte  ...  10383272.89    9126101.17
# 20              41 Paraná           Sul  ... 151689447.35  147664376.34
# 23  50 Mato Grosso do Sul  Centro-Oeste  ...  25831953.20   30064692.74
# 2             13 Amazonas         Norte  ...  19720814.02   17413494.69
# 19           35 São Paulo       Sudeste  ... 379315637.93  328079700.38
#
# [5 rows x 166 columns]

# %%
#Apenas pegamos valores númericos
colunas_usaveis_random = random_estados.mean().index.tolist()

#Inserindo a unidade da federação na nossa lista
colunas_usaveis_random.insert(0, "Unidade da Federação")

#inserindo as colunas que não possuem valores não númericos dentro de um df a ser plotado
usaveis_random = random_estados[colunas_usaveis]
#inserindo unidade da federação como nosso index
usaveis_random = usaveis_random.set_index("Unidade da Federação")
#retornando nosso df
usaveis_random
# Out:
#                         2008/Jan     2008/Fev  ...     2021/Jul      2021/Ago
# Unidade da Federação                           ...
# 16 Amapá               841750.93    935697.28  ...   4178106.27             0
# 25 Paraíba            8580988.49   9050986.31  ...  23748222.18   22309732.68
# 53 Distrito Federal   3720571.62   5939369.45  ...  24260713.04   22230655.33
# 33 Rio de Janeiro    19262626.17  23581216.45  ... 108886786.43  101698436.48
# 35 São Paulo         74734672.12 121839337.46  ... 379315637.93  328079700.38
#
# [5 rows x 163 columns]

# %%
#garantindo que todos os valores serão númericos e plotaveis
usaveis_random_transpose = usaveis_random.T.astype(float)
#plotando o bixão
usaveis_random_transpose = usaveis_random_transpose.plot(figsize=(25,12))
usaveis_random_transpose.legend(loc='center left', bbox_to_anchor=(1.1, 0.5))
usaveis_random_transpose.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.title("Valor Gasto em R$ por unidade da federação")
# Out:
# Text(0.5, 1.0, 'Valor Gasto em R$ por unidade da federação')

# %%
#dados_sudeste = dados_estados.query("Região == 'Sudeste'")
#dados_norte = dados_estados.query("Região == 'Norte'")
#dados_nordeste = dados_estados.query("Região == 'Nordeste'")
#dados_Sul = dados_estados.query("Região == 'Nordeste'")
#dados_norte.T

# %%
#criando lista de regioes
lista_regioes = dados_estados.Região.unique()
lista_regioes = lista_regioes.tolist()
if 'Total' in lista_regioes:
  lista_regioes.remove('Total')

# %%
#criando iteração para agrupar por região..(dava para fazer por groupby mas queria brincar com lists)
total_regioes = []
total_regioes = pd.DataFrame(total_regioes)
ignore = ['Unidade da Federação', 'Região', 'Total']
for regiao in lista_regioes:
  tempo = dados_estados.query("Região == @regiao")
  temp = tempo.drop(ignore,axis=1)
  temp_t = temp.T.astype(float)
  total_regioes[regiao] = temp_t.sum(axis=1)

total_regioes
# Out:
#                Norte     Nordeste      Sudeste          Sul  Centro-Oeste
# 2008/Jan 23751045.23  74651426.82 135073946.79  70386981.16   24219054.90
# 2008/Fev 29308004.95 105369170.74 209280005.76 113738740.83   36652587.29
# 2008/Mar 31906429.56 120056805.64 236346508.60 107900668.92   38022219.05
# 2008/Abr 30208362.24 131259493.74 238982540.60 111970636.82   39860151.80
# 2008/Mai 32268796.89 131345542.74 262404774.46 106175068.05   43067845.03
# ...              ...          ...          ...          ...           ...
# 2021/Abr 86716621.43 392696936.21 684923086.92 319759754.97  130183178.98
# 2021/Mai 97327679.65 430094989.78 726705746.09 331092912.85  123842502.06
# 2021/Jun 87621136.83 460597757.13 747483861.33 354517917.88  133661986.28
# 2021/Jul 83510402.06 431565821.13 744030171.97 360433407.10  140677701.70
# 2021/Ago 72407376.15 345445165.89 660032113.11 339366846.21  139646488.53
#
# [164 rows x 5 columns]

# %%
#Plotando o bixao
total_regioes_plt = total_regioes.plot(figsize=(25,12))
total_regioes_plt.legend(loc='center left', bbox_to_anchor=(1.1, 0.5))
total_regioes_plt.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.title("Valor Gasto em R$ por unidade da federação")
# Out:
# Text(0.5, 1.0, 'Valor Gasto em R$ por unidade da federação')

# %%
# ／ʕ •ᴥ•ʔ／ Escreva o ano que deseja buscar no formato ####. ／ʕ •ᴥ•ʔ／
# ／ʕ •ᴥ•ʔ／Só buscamos 1 ano de cada vez, função de históricos multiplo não habilitada. ／ʕ •ᴥ•ʔ／

ano_buscado = '2013'
#Lista dos meses
lista_meses = ['Jan','Fev','Mar','Abr','Mai','Jun','Jul','Ago','Set','Out','Nov','Dez']
lista_ano = []
#criando lista
for meses in lista_meses:
  temp1 = ano_buscado + '/' + meses
  lista_ano.append(temp1)


total_regioes_ano = total_regioes.loc[lista_ano]

total_regioes_ano_plt = total_regioes_ano.plot(figsize=(15,10))
total_regioes_ano_plt.legend(loc='center left', bbox_to_anchor=(1.1, 0.5))
total_regioes_ano_plt.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.title("Valor Gasto em R$ por unidade da federação no ano de %s" %(ano_buscado))
# Out:
# Text(0.5, 1.0, 'Valor Gasto em R$ por unidade da federação no ano de 2013')

# %%
# ／ʕ •ᴥ•ʔ／ Progressão 2008 até 2020 acumulado ／ʕ •ᴥ•ʔ／



#Lista dos meses
lista_meses = ['Jan','Fev','Mar','Abr','Mai','Jun','Jul','Ago','Set','Out','Nov','Dez']
lista_ano = ['2008','2009','2010','2011','2012','2013','2014','2015','2016','2017','2018','2019','2020']
lista_append = []

#criando lista
for anos in lista_ano:
  ano_buscado = anos
  for meses in lista_meses:
    if ano_buscado == '2021':
      pass 
    else: 
      temp1 = ano_buscado + '/' + meses
      lista_append.append(temp1)
  total_regioes_ano = total_regioes.loc[lista_append]
  total_regioes_ano_plt = total_regioes_ano.plot(figsize=(8,4))
  total_regioes_ano_plt.legend(loc='center left', bbox_to_anchor=(1.1, 0.5))
  total_regioes_ano_plt.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
  plt.title("Valor Gasto em R$ por unidade da federação no ano de 2008 até o ano de  %s" %(ano_buscado))

# %%
# ／ʕ •ᴥ•ʔ／ Progressão 2008 até 2020 ano a ano ／ʕ •ᴥ•ʔ／



#Lista dos meses
lista_meses = ['Jan','Fev','Mar','Abr','Mai','Jun','Jul','Ago','Set','Out','Nov','Dez']
lista_ano = ['2008','2009','2010','2011','2012','2013','2014','2015','2016','2017','2018','2019','2020']
lista_append = []

#criando lista
for anos in lista_ano:
  ano_buscado = anos
  lista_append = []
  for meses in lista_meses:
    
    if ano_buscado == '2021':
      pass 
    else: 
      temp1 = ano_buscado + '/' + meses
      lista_append.append(temp1)
  total_regioes_ano = total_regioes.loc[lista_append]
  total_regioes_ano_plt = total_regioes_ano.plot(figsize=(8,4))
  total_regioes_ano_plt.legend(loc='center left', bbox_to_anchor=(1.1, 0.5))
  total_regioes_ano_plt.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
  plt.title("Valor Gasto em R$ por unidade da federação no ano de %s" %(ano_buscado))
